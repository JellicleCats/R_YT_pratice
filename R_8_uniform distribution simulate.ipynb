# %%
# uniform distribution simulate
roll <- 1000000
n <- 6
die <- ceiling( runif(roll)*n)
b <- table(die)
barplot(b)
# Out:
# plot without title

# %%
# uniform distribution simulate
roll <- 1000000
n <- 6
die <- ceiling( runif(roll)*n)
b <- table(die)
barplot(b)
